# %%
import pandas as pd

df = pd.read_csv('ujung.csv', encoding='utf-8-sig', index_col=0)

# %%
df.head(5)
# Out:
#                         _id user_id                      time  \
# 0  67430fbc0c898a183d4f9641  gh0422  2024-05-26T07:25:18.000Z
# 1  67430fbc0c898a183d4f9643  gh0422  2024-05-25T16:55:54.000Z
# 2  67430fbc0c898a183d4f9649  gh0422  2024-05-24T20:14:00.000Z
# 3  67430fbc0c898a183d4f964c  gh0422  2024-05-24T13:31:24.000Z
# 4  67430fbc0c898a183d4f964d  gh0422  2024-05-24T12:20:17.000Z
#
#                                                 url  \
# 0  https://www.threads.net/@gh0422/post/C7bFgLsyDqq
# 1  https://www.threads.net/@gh0422/post/C7ZiAb0y7QS
# 2  https://www.threads.net/@gh0422/post/C7XT4h1ScCA
# 3  https://www.threads.net/@gh0422/post/C7Wlzzcykh0
# 4  https://www.threads.net/@gh0422/post/C7Wdq7SyBrv
#
#                                                 text  \
# 0  읽씹,안읽씹내가 눈치가 없는걸까? 바로 전 카톡까지만 해도 나를 걱정하는 말.혹은 ...
# 1  남 탓으로 돌리는게 아니야.난 이해받지 못하는 인간이지만간절히 이해받고 싶던 인간이...
# 2  오늘은 나쁜꿈 슬픈꿈 안꾸게 해주세요🙏한번 크게 힘든 꿈 꾸고나면 안그래도 잘 못자...
# 3  과연 나는 누군가가 감싸줄만한 사람일까?누구나 절대 선으로만 인생을 살아오지는 않았...
# ...

# %%
df['word_embeddings']
# Out:
# 0       {'일러스트': array([[ 2.08431482e-01, -8.82843733e...
# 1       {'이해': array([[ 2.08431482e-01, -8.82843733e-0...
# 2       {'오늘': array([[ 3.96649651e-02, -3.41148376e-0...
# 3       {'죄인': array([[ 2.08431482e-01, -8.82843733e-0...
# 4       {'해방감': array([[ 2.08431482e-01, -8.82843733e-...
#                               ...
# 5416    {'우발': array([[ 2.08431482e-01, -8.82843733e-0...
# 5417    {'목숨': array([[ 2.08431482e-01, -8.82843733e-0...
# 5418    {'옥상': array([[ 2.08431482e-01, -8.82843733e-0...
# 5419                                                   {}
# 5420    {'티아': array([[ 2.08431482e-01, -8.82843733e-0...
# Name: word_embeddings, Length: 5421, dtype: object

# %%
print(df['word_embeddings'].iloc[0])
